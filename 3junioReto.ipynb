# %% [markdown]
# <a href="https://colab.research.google.com/github/bogdanganea37-dev/EjerciciosPyton/blob/main/3junioReto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = input("¿Cual es tu nombre? ")
print(input("¿Cual es tu edad? "))
respuesta_pizza = input("Te gusta la pizza? ")

if respuesta_pizza.lower() == "si":
  print (f"Enhorabuena!! {nombre}, has ganado una pizza")
else:
  print (f"Enhorabuena!! {nombre}, has ganado una hamburguesa")
print ("Gracias por participar y le esperamos pronto de vuelta")
